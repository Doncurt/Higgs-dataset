# %% [markdown]
# # Higgs Boson detection in experiments from the LHC
#
#
#
# #### ==================================================
#
#
#
# ##### The following are a collection of  measurments of particles that were the result experiments derived from the collision of particles at CERN's Large Hadron Collider.
#
# #### The Large Hadron Collider
#
# ##### Considered to be the most advanced and one of the most precise peices of machinery to ever be asssembled, this almost 17 mile length tunnel lined with super conducting magnets accelerates particles near the speed of light in order to study the energy and  particles produced by the collisions of such particles. The particles are contained in an unltra high vaccum in order not to just reduce resistance, but to completely isolate the particles. This results in the most accurate measurement s possible for each collison, and eschews the chance of interfernce from outside pressures, radiations, energies or particles.
#
#
# #### The Standard Model and BSM
#
# ##### While the Standard Model seeks to describe the interactions of fundamental particles at the quantum level, LHC experiments are designed to test the properties of matter beyond the Standar Model of physics(BSM). This includes particles such as  multiple flavors of positively charged leptons (and their neutral counterparts, neutrinos. The most widely known lepton is the electron), and various types of bosons. The most important particle specifically for this experiment is the  detection of the Higgs Boson and the measured results are used to test and produce new theories in BSM physics.
#
# #### The Higgs Boson
# ##### The importance of this particle in modern physics cannot be understated. Considered a "missing link" in the standard model, the presence of this particle after being solely theoretical for almost half a century, gives validity to the entirety of the standard model of physics.
#
# #### Detection of the Higgs Boson
# ##### Higgs Bosons are usually detected ( from doing this dataset and the associated research) generally occur the most in collisions where the observed lepton_eta , lepton_phi, and missing_energy_phi having median values of 0.001894, 0.000971 and 0.002060 respectively. On the other side of this the median at which the didnt occur( and should not be tested at in later sets since it's not helping the predictions) have median values of 0.000920, -0.003570 and 0.000100 respectively

# %% [markdown]
# ## Glossary
# ##### Torodial - Donut shaped, the shape itself being important for collisions, measuments and modeling of events at the sub-atomic level

# %% [markdown]
# ## Initial Data Load

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
# thers 28 columns to this trunicated
pd.set_option('display.max_columns', 500)
np.random.seed(42)

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
#Take a look at the data
# print(pd.read_csv(file, nrows=5))

# %%
column_names = ['sig_or_back','lepton_pT', 'lepton_eta', 'lepton_phi', 'missing_energy_magnitude', 'missing_energy_phi', 'jet_1_pt', 'jet_1_eta', 'jet_1_phi', 'jet_1_b-tag', 'jet_2_pt', 'jet_2_eta', 'jet_2_phi', 'jet_2_b-tag', 'jet_3_pt', 'jet_3_eta', 'jet_3_phi', 'jet_3_b-tag', 'jet_4_pt', 'jet_4_eta', 'jet_4_phi', 'jet_4_b-tag', 'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb','m_wwbb']
#column names for later

# %%
# pandas csv text
# set the table name
table_name='higgs'
# set the database uri to connect to
con='postgresql://donovanadams:Dad8e3cc@localhost:5432/datascience'
# the sql query well need
# did a normal distribution off of the notebook and found that the first 1000000 sample matches the given data in terms of stats
sql = 'SELECT * FROM higgs LIMIT 1000000;'
# chunking, for some reazont it gives a key error
df_all_rows_and_columns = pd.read_sql_query(sql,con, index_col=None, coerce_float=True, params=None,
             parse_dates=None, chunksize=None)

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ### Data size
# #### The data contains 29 columns and 10,999,999 rows for a total of 318,999,971 measured data points
# #### Doing a  Gaussian distributin of the entire data set let to the first 1000000 being discovered ad pretty much representative of the entire sample

# %%
#testing data length
sql_count = 'SELECT COUNT(*)FROM higgs'
df_all_rows_and_columns_row_amount =pd.read_sql_query(sql_count,con)

# %%
df_all_rows_and_columns_row_amount

# %%
#get total counts
sql_head = 'SELECT * FROM higgs LIMIT 10;'
df_all_rows_and_columns_head = pd.read_sql_query(sql_head,con)
df_all_rows_and_columns_head

# %%
# This will at first print in scientific notation due to some of the measurements involved

df_all_rows_and_columns.describe()
# Out:
#           sig_or_back       lepton_pt      lepton_eta      lepton_phi  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.530247        0.991743        0.000459       -0.000874
# std          0.499085        0.565644        1.008984        1.006978
# min          0.000000        0.274697       -2.434980       -1.742510
# 25%          0.000000        0.590570       -0.738322       -0.873041
# 50%          1.000000        0.853737       -0.000054       -0.002461
# 75%          1.000000        1.236590        0.739188        0.871549
# max          1.000000       10.381200        2.434870        1.743240
#
#        missing_energy_magnitude  missing_energy_phi        jet_1_pt  \
# count            1000000.000000      1000000.000000  1000000.000000
# mean                   0.999347            0.000189        0.990050
# std                    0.599987            1.006277        0.474265
# ...

# %% [markdown]
# ## Grouping by Signal or Background ( for signal or background)

# %%
signal_present_group_sql = "SELECT * FROM higgs WHERE sig_or_back =1.0 LIMIT 1000000"
signal_present_df= pd.read_sql_query(signal_present_group_sql,con)
signal_present_df.describe()
# Out:
#        sig_or_back       lepton_pt      lepton_eta      lepton_phi  \
# count    1000000.0  1000000.000000  1000000.000000  1000000.000000
# mean           1.0        0.966601        0.001011        0.000554
# std            0.0        0.506000        0.997564        1.005950
# min            1.0        0.274697       -2.434980       -1.742510
# 25%            1.0        0.601917       -0.728583       -0.870266
# 50%            1.0        0.848430        0.001894        0.000971
# 75%            1.0        1.197250        0.730422        0.872104
# max            1.0        6.154050        2.434870        1.743240
#
#        missing_energy_magnitude  missing_energy_phi        jet_1_pt  \
# count            1000000.000000      1000000.000000  1000000.000000
# mean                   0.941716            0.001149        1.016472
# std                    0.527316            1.005969        0.482208
# min                    0.000576           -1.743940        0.138235
# ...

# %%
# By those that reported that the readings were from the background
background_present_group_sql = "SELECT * FROM higgs WHERE sig_or_back =0.0 LIMIT 1000000"
background_present_df= pd.read_sql_query(background_present_group_sql,con)
background_present_df
# Out:
#        sig_or_back       lepton_pt      lepton_eta      lepton_phi  \
# count    1000000.0  1000000.000000  1000000.000000  1000000.000000
# mean           0.0        1.020871        0.000267       -0.002114
# std            0.0        0.625350        1.021208        1.006557
# min            0.0        0.274697       -2.434980       -1.742510
# 25%            0.0        0.577760       -0.750010       -0.873595
# 50%            0.0        0.861790        0.000920       -0.003570
# 75%            0.0        1.286000        0.750876        0.869884
# max            0.0       12.098900        2.434870        1.743240
#
#        missing_energy_magnitude  missing_energy_phi        jet_1_pt  \
# count            1000000.000000      1000000.000000  1000000.000000
# mean                   1.063465            0.000285        0.962276
# std                    0.666746            1.005754        0.463539
# min                    0.000992           -1.743940        0.138602
# ...

# %% [markdown]
# ## Exploring the Missing Energy Magnitude

# %%
miss_energy_mag_sql = 'SELECT missing_energy_magnitude FROM higgs;'
miss_energy_mag_df= pd.read_sql_query(miss_energy_mag_sql,con)
miss_energy_mag_df.describe()
# Out:
#        missing_energy_magnitude
# count              1.100000e+07
# mean               9.985364e-01
# std                6.000185e-01
# min                2.370090e-04
# 25%                5.768160e-01
# 50%                8.916280e-01
# 75%                1.293060e+00
# max                1.539680e+01

# %%
# lepton_eta- the length of time that the lepton is observed have wildy different 
# median values, with the occurrences with signal detected having much higher etas at 0.001894
# Occurences with  backround detected coming in at around 0.000920
occurence_with_signal_sql = 'SELECT missing_energy_magnitude,lepton_eta,lepton_pt FROM higgs WHERE sig_or_back =1.0 LIMIT 1000000;'
occurence_with_signal_df = pd.read_sql_query(occurence_with_signal_sql,con)
occurence_with_signal_df.describe()
# Out:
#        missing_energy_magnitude      lepton_eta       lepton_pt
# count            1000000.000000  1000000.000000  1000000.000000
# mean                   0.941878       -0.000125        0.965848
# std                    0.527368        0.997880        0.505751
# min                    0.000730       -2.434980        0.274697
# 25%                    0.561709       -0.730531        0.601002
# 50%                    0.858896        0.000920        0.847698
# 75%                    1.225572        0.729448        1.196330
# max                    7.568670        2.434870        6.602600
